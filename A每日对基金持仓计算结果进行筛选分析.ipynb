# %%
import pandas as pd
from datetime import datetime
today = str(datetime.now().date())
# df=pd.read_excel(r'D:\jijin result\ '+today+"基金统计结果全.xlsx")
df=pd.read_excel(today+"基金统计结果全.xlsx")
#筛选条件如下
df=df[df['60次数-60次数j']>=0]
df=df[df['60次数']>=6]
df=df[(df['10次数']<=3)&(df['5次数']<=2)]
#显示结果
df2=df[["60次数-60次数j","60次数","60次数j","10次数","5次数","基金代码","综合","综合1","基金简称","股票次数总和","基金十大重仓股票"]]
print(df2)
# Out:
#     60次数-60次数j  60次数  60次数j  10次数  5次数       基金代码  综合  综合1           基金简称  \
# 52           1     8      7     2    2  515750.OF  13   12  富国中证科技50策略etf
#
#     股票次数总和                                           基金十大重仓股票
# 52    3526  宁德时代,300750||中兴通讯,000063||广联达,002410||恒瑞医药,600...

# %%
import pandas as pd
from datetime import datetime
today = str(datetime.now().date())
# df=pd.read_excel(r'D:\jijin result\ '+today+"基金统计结果全.xlsx")
df=pd.read_excel(today+"基金统计结果全.xlsx")
#筛选条件如下
df=df[(df['250次数-250次数j']>=1)&(df['60次数-60次数j']>=1)]
df=df[df['250次数']>=5]
df=df[df['60次数']>=5]
#显示结果
df3=df[["和250差和60差","基金代码","综合","综合1","基金简称","股票次数总和","基金十大重仓股票"]]
print(df3)
# Out:
#     和250差和60差       基金代码  综合  综合1                基金简称  股票次数总和  \
# 0           7  160631.OF   2   -1                鹏华银行    3446
# 1           7  512700.OF   2   -1           南方中证银行etf    3446
# 2           7  512730.OF   2   -1           鹏华中证银行etf    3446
# 3           5  512800.OF   1   -1               银行etf    3429
# 4           5  512820.OF   1   -1             中证银行etf    3429
# 6           4  161728.SZ   0   -1   招商3年封闭运作战略配售(lof)    5636
# 7           3  501188.SH   4    2                添富配售    7057
# 9           2  161131.SZ   3    2  易方达3年封闭战略配售混合(lof)    7529
# 11          2  501079.SH   6    5  大成科创主题3年封闭运作灵活配置混合    2680
# 13          2  501080.SH   8    7              中金科创主题    3766
# 14          2  160926.OF   9    8        大成创业板两年定开混合a    2651
# 15          2  159905.OF   3    2            工银深红利etf    6928
#
#                                              基金十大重仓股票
# 0   招商银行,600036||兴业银行,601166||平安银行,000001||工商银行,60...
# ...

# %%
import pandas as pd
from datetime import datetime
today = str(datetime.now().date())
# df=pd.read_excel(r'D:\jijin result\ '+today+"基金统计结果全.xlsx")
df=pd.read_excel(today+"基金统计结果全.xlsx")
#筛选条件如下
#筛选条件如下
df=df[(df['250次数-250次数j']>=1)|(df['60次数-60次数j']>=1)]
df=df[df['250次数']>=5]
df=df[df['60次数']>=5]
#显示结果
df1=df[["250次数-250次数j","60次数-60次数j","基金代码","综合","综合1","基金简称","股票次数总和","基金十大重仓股票"]]
print(df1)
# Out:
#      250次数-250次数j  60次数-60次数j       基金代码  综合  综合1                基金简称  股票次数总和  \
# 0               4           3  160631.OF   2   -1                鹏华银行    3446
# 1               4           3  512700.OF   2   -1           南方中证银行etf    3446
# 2               4           3  512730.OF   2   -1           鹏华中证银行etf    3446
# 3               3           2  512800.OF   1   -1               银行etf    3429
# 4               3           2  512820.OF   1   -1             中证银行etf    3429
# 6               3           1  161728.SZ   0   -1   招商3年封闭运作战略配售(lof)    5636
# 7               1           2  501188.SH   4    2                添富配售    7057
# 9               1           1  161131.SZ   3    2  易方达3年封闭战略配售混合(lof)    7529
# 10              3          -1  159940.OF  -1    0       广发中证全指金融地产etf    6344
# 11              1           1  501079.SH   6    5  大成科创主题3年封闭运作灵活配置混合    2680
# 13              1           1  501080.SH   8    7              中金科创主题    3766
# ...
